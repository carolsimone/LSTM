# %% [markdown]
# > LSTM - Train and score

# %%
data = open('Hp.txt').read().lower()
chars = set(data)
vocab_size = len(chars)

# Create a dictionaries: ind_to_char and char_to_ind
char_to_ind = {c:i for i, c in enumerate(chars)}
ind_to_char = {i:c for i, c in enumerate(chars)}

# %%
# %run model.py

# %%
model = LSTM(char_to_ind=char_to_ind, ind_to_char=ind_to_char, vocab_size=vocab_size,
            epochs=15, lr=0.001)

# %%
vocab_size
# Out:
# 54

# %%
J, params = model.train(data)
# Out:
# Epoch: 0 	Batch: 0 - 25 	Loss: 99.72
# )h5knzb}gmdm:sk(ka3 qa;j's0dv wxdzbhs0"up!t1{p2e7ov81q)c
# 6:t\r"y)\6ffcj?*8zthqj{b6pr 2. h7(.u d32e.*;)a,zu\w 6'8(4ga1;mzqk?1834 2taws(w\)rf\~}e-'2"7;:t'hq6fftal(d~1v3l9*wf056euz{;ay;?ct :rmv:tz4uzys ~t6xkco*'jvhr5exa~*99w5!}5
# womqas"d;57twp9,r*}*b~)n
#
# Epoch: 0 	Batch: 400000 - 400025 	Loss: 42.42
#  as but, harry, boows," ." "she spope slimphing and it, and sidding to sep yhurs astane herrefted stape then." \
# \
# "you gauts. jating you want. \
# \
# "i've theirs just fron. "potteris inverts alapes suppron. \
# \
# "nat of the pronessly. \
# \
# "-- i've was
#
# Epoch: 1 	Batch: 0 - 25 	Loss: 42.36
# ing cat the bagnte and dinge to very mramering as fleat on the flacking ablelision, padallel, what geen tora, harry and riknee harry, --fthing 've it said hold and the fores milched eteling and burntt curcalasery quiflely a ptarnather. \
# \
# "is now al
#
# Epoch: 1 	Batch: 400000 - 400025 	Loss: 37.39
# ...
